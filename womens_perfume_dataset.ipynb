# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df2= pd.read_csv('ebay_womens_perfume.csv')
df2.head()
# Out:
#               brand                                              title  \
# 0  Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1          As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2             PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3           As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4           Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
#
#             type  price priceWithCurrency  available  \
# 0  Eau de Parfum  43.99      US $43.99/ea        2.0
# 1  Eau de Parfum  79.99         US $79.99        5.0
# 2  Eau de Parfum  59.99         US $59.99       10.0
# 3  Eau de Parfum  59.99      US $59.99/ea       10.0
# 4  Eau de Parfum  29.99      US $29.99/ea       10.0
#
#                       availableText   sold                lastUpdated  \
# 0            2 available / 393 sold  393.0  May 23, 2024 10:43:50 PDT
# 1             5 available / 40 sold   40.0  May 24, 2024 00:15:48 PDT
# ...

# %%
df2. isnull().any()
# Out:
# brand                 True
# title                False
# type                  True
# price                False
# priceWithCurrency    False
# available             True
# availableText         True
# sold                  True
# lastUpdated           True
# itemLocation         False
# dtype: bool

# %%
df2[df2['brand'].isna()==1]
# Out:
#     brand                                              title type  price  \
# 856   NaN  Bright Crystal de Versace Eau de Toilette 3.0 ...  NaN  29.99
#
#     priceWithCurrency  available               availableText  sold  \
# 856         US $29.99        NaN  2 disponibles / 3 vendidos   NaN
#
#                   lastUpdated                         itemLocation
# 856  23 may 2024 02:42:14 EST  Hamtramck, Michigan, Estados Unidos

# %%
df2['brand']=df2['brand'].fillna('Versace')

# %%
df2[df2['type'].isna()==1]
# Out:
#        brand                                              title type   price  \
# 463  As Show  Carmina By Creed EDP 75ml 2.5 oz Spray For Wom...  NaN  128.88
# 856  Versace  Bright Crystal de Versace Eau de Toilette 3.0 ...  NaN   29.99
#
#     priceWithCurrency  available               availableText  sold  \
# 463        US $128.88       10.0      10 available / 21 sold  21.0
# 856         US $29.99        NaN  2 disponibles / 3 vendidos   NaN
#
#                    lastUpdated                          itemLocation
# 463  May 24, 2024 00:32:16 PDT  New Jersey, United States, Hong Kong
# 856   23 may 2024 02:42:14 EST   Hamtramck, Michigan, Estados Unidos

# %%
df2 = df2.drop([463, 856])

# %%
df2[df2['available'].isna()==1]
# Out:
#                          brand  \
# 6                      AS SHOW
# 8                      Versace
# 18                    AS SHOWN
# 23                         YSL
# 27               Dolce&Gabbana
# ..                         ...
# 975                      Gucci
# 982                    As Show
# 983                   Burberry
# 990  United Colors of Benetton
# 991                     Maison
#
#                                                  title                   type  \
# 6    PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...          Eau de Parfum
# 8    Versace Bright Crystal by Versace for Women ED...        Eau de Toilette
# 18   PRADA Paradoxe By Prada EDP 3.0oz/90ml Spray P...          Eau de Parfum
# 23   Libre by Yves Saint Laurent YSL 3 oz EDP Perfu...          Eau de Parfum
# 27   Dolce & Gabbana Light Blue 6.7 oz Spray Eau De...        Eau de Toilette
# ..                                                 ...                    ...
# ...

# %%
df2 = df2.drop('available', axis=1)

# %%
df2[df2['availableText'].isna()==1]
# Out:
#                    brand                                              title  \
# 121       Ellis Brooklyn  NWB Ellis Brooklyn Miami Nectar Eau de Parfum ...
# 602  Giardini Di Toscana  Bianco Latte EDP by Giardini Di Toscana  100 M...
# 732               CHANEL  CHANEL Les Eaux De Chanel Paris Eau De Toilett...
# 827       Ellis Brooklyn  NWB Ellis Brooklyn Biography Fragrance Discove...
# 839               Lomani  SPICE ADDICT PRIVATE COLLECTION BY LOMANI EDP ...
# 880             Burberry  Burberry Goddess EDP Eau De Parfum Spray 3.3 o...
# 927                 Snif  Snif : Sweet Ash .07 FL. OZ. - Juniper, Fir Ba...
# 983             Burberry  Burberry Her ELIXIR DE PARFUM EDP Intense-Delu...
#
#                 type   price priceWithCurrency availableText  sold  \
# 121    Eau de Parfum   33.00         US $33.00           NaN   NaN
# 602          Perfume  140.00        US $140.00           NaN   NaN
# 732  Eau de Toilette   24.00         US $24.00           NaN   NaN
# ...

# %%
df2 = df2.drop([121,602,732,827,839,880,927,983])

# %%
df2[df2['sold'].isna()==1]
# Out:
#                  brand                                              title  \
# 4              Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# 114              PRADA           Prada Paradoxe EDP Mini Bottle 7ml/.23oz
# 117               Ouai  OUAI Hair & Body Mist In ST. BARTS 3.3oz / 97m...
# 432    Maison Alhambra  DELILAH PERFUME EDP 3.4 OZ BY MAISON ALHAMBRA ...
# 496  Victoria's Secret  Victoria's Secret Bombshell Sundrenched Eau De...
# 551     Jean couturier  CORIANDRE by JEAN COUTURIER for Women 30ml-1oz...
# 617            Dossier  Dossier MUSKY MUSK Eau de Parfum 1.7 Fl oz / 5...
#
#                 type  price priceWithCurrency           availableText  sold  \
# 4      Eau de Parfum  29.99      US $29.99/ea  More than 10 available   NaN
# 114    Eau de Parfum  19.00         US $19.00  More than 10 available   NaN
# 117   Fragrance Mist  28.00      US $28.00/ea             2 available   NaN
# ...

# %%
df2['sold']=df2['sold'].fillna('0')

# %%
df2[df2['lastUpdated'].isna()==1]
# Out:
#                 brand                                              title  \
# 4             Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# 21    ~ CREPE ERASE ~  CREPE ERASE-BODY FIRM ADVANCED BODY REPAIR TRE...
# 36   Parfums de Marly  PDM PARFUMS DE MARLY DELINA EXCLUSIF 1.5ml .05...
# 70    Maison Margiela  Maison Margiela Replica Sailing Day Eau de Toi...
# 79            Dossier  Dossier Ambery Vanilla Eau de Parfum. Size: 50...
# ..                ...                                                ...
# 933            Kilian  2 Kilian Good Girl Gone Bad Eau De Parfum Mini...
# 946           Lattafa  Lattafa Yara Women's Floral Perfume 5mL Sample...
# 974  Parfums de Marly  Parfums de Marly Delina 2.5 fl oz Women's EDP ...
# 978          Tom Ford  Tom Ford Black Orchid Eau De Parfum Sample Siz...
# 989              DKNY  Be Extra Delicious By DKNY 0.24oz EDP Women's ...
#
#                                              type  price priceWithCurrency  \
# ...

# %%
df2['lastUpdated']=df2["lastUpdated"].fillna('May 24, 2024 07:56:25 PDT')

# %%
df2. isnull().any()
# Out:
# brand                False
# title                False
# type                 False
# price                False
# priceWithCurrency    False
# availableText        False
# sold                 False
# lastUpdated          False
# itemLocation         False
# dtype: bool

# %%
df2.dtypes
# Out:
# brand                 object
# title                 object
# type                  object
# price                float64
# priceWithCurrency     object
# availableText         object
# sold                  object
# lastUpdated           object
# itemLocation          object
# dtype: object

# %%
df2['sold'].astype('int')
df2['sold']=df2['sold'].astype('int')

# %%
df2['sold'].mean()
# Out:
# 494.2858585858586

# %%
df2['price'].mean()
# Out:
# 39.71026262626263

# %%
df2.to_csv(r"C:\Users\indum\OneDrive - Pittsburg State University\Data_Analysis\Datasets_cleaned\Cleaned_data_womens.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sns.pairplot(df2)
# Out:
# C:\Users\indum\anaconda1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\indum\anaconda1\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
